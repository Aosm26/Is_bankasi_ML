# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer

# %%
data=pd.read_csv('train_final_hundred.csv')
columnnames=['id','month','n_seconds_1','n_seconds_2','n_seconds_3','carrier','devicebrand','feature_0','feature_1','feature_2','feature_3','feature_4','feature_5','feature_6','feature_7','feature_8','feature_9','feature_10','feature_11','feature_12','feature_13','feature_14','feature_15','feature_16','feature_17','feature_18','feature_19','feature_20','feature_21','feature_22','feature_23','feature_24','feature_25','feature_26','feature_27','feature_28','feature_29','feature_30','feature_31','feature_32','feature_33','feature_34','feature_35','feature_36','feature_37','feature_38','feature_39','feature_40','feature_41','feature_42','feature_43','feature_44','feature_45','feature_46','feature_47','feature_48','feature_49','menus']
data.columns=columnnames
#data.head()


# Yeni sütunları oluşturun
data["menus_1"] = 0
data["menus_2"] = 0
data["menus_3"] = 0
data["menus_4"] = 0
data["menus_5"] = 0
data["menus_6"] = 0
data["menus_7"] = 0
data["menus_8"] = 0
data["menus_9"] = 0



data.head()

a=0
for menus in data['menus']:
   print(a)
   print(menus)
   menu_sirasi=0
   for menu in menus :
     gelen_veri = menu #menu2
     sayisal_veri = 0

     for karakter in gelen_veri:
        if karakter.isdigit():  # Karakter bir sayı ise
           sayisal_veri += int(karakter)
           print(sayisal_veri)
     if(sayisal_veri !=0):
       menu_sirasi+=1
       label=f'menus_{sayisal_veri}'
       label2=f'n_seconds_{menu_sirasi}'
       data.loc[a, label] = data.loc[a,label2]
       print(label)
   a+=1
data = data.fillna(0)
# Verisetini kaydedin
data.to_csv("train_final2.csv",index=False)
data.head()
# Out:
# 0
# menu7, menu8, menu4
# 7
# menus_7
# 8
# menus_8
# 4
# menus_4
# 1
# menu2, menu8, menu4
# 2
# menus_2
# 8
# menus_8
# 4
# menus_4
# 2
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 3
# menu6, menu2, menu8
# 6
# menus_6
# 2
# menus_2
# 8
# menus_8
# 4
# menu6, menu2, menu9
# 6
# menus_6
# 2
# menus_2
# 9
# menus_9
# 5
# menu2, menu1, menu8
# 2
# menus_2
# 1
# menus_1
# 8
# menus_8
# 6
# menu7, menu2, menu1
# 7
# menus_7
# 2
# menus_2
# 1
# menus_1
# 7
# menu6, menu2, menu9
# 6
# menus_6
# 2
# menus_2
# 9
# menus_9
# 8
# menu2, menu4, menu5
# 2
# menus_2
# 4
# menus_4
# 5
# menus_5
# 9
# menu6, menu2, menu4
# 6
# menus_6
# 2
# menus_2
# 4
# menus_4
# 10
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 11
# menu6, menu2, menu9
# 6
# menus_6
# 2
# menus_2
# 9
# menus_9
# 12
# menu7, menu2, menu1
# 7
# menus_7
# 2
# menus_2
# 1
# menus_1
# 13
# menu6, menu2, menu8
# 6
# menus_6
# 2
# menus_2
# 8
# menus_8
# 14
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 15
# menu6, menu2, menu8
# 6
# menus_6
# 2
# menus_2
# 8
# menus_8
# 16
# menu2, menu1, menu4
# 2
# menus_2
# 1
# menus_1
# 4
# menus_4
# 17
# menu2, menu4, menu5
# 2
# menus_2
# 4
# menus_4
# 5
# menus_5
# 18
# menu2, menu1, menu4
# 2
# menus_2
# 1
# menus_1
# 4
# menus_4
# 19
# menu9, menu2, menu4
# 9
# menus_9
# 2
# menus_2
# 4
# menus_4
# 20
# menu2, menu4, menu5
# 2
# menus_2
# 4
# menus_4
# 5
# menus_5
# 21
# menu6, menu2, menu9
# 6
# menus_6
# 2
# menus_2
# 9
# menus_9
# 22
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 23
# menu6, menu2, menu5
# 6
# menus_6
# 2
# menus_2
# 5
# menus_5
# 24
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 25
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 26
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 27
# menu2, menu8, menu5
# 2
# menus_2
# 8
# menus_8
# 5
# menus_5
# 28
# menu9, menu3, menu6
# 9
# menus_9
# 3
# menus_3
# 6
# menus_6
# 29
# menu6, menu2, menu9
# 6
# menus_6
# 2
# menus_2
# 9
# menus_9
# 30
# menu9, menu2, menu4
# 9
# menus_9
# 2
# menus_2
# 4
# menus_4
# 31
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 32
# menu6, menu2, menu5
# 6
# menus_6
# 2
# menus_2
# 5
# menus_5
# 33
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 34
# menu6, menu2, menu5
# 6
# menus_6
# 2
# menus_2
# 5
# menus_5
# 35
# menu6, menu2, menu9
# 6
# menus_6
# 2
# menus_2
# 9
# menus_9
# 36
# menu6, menu2, menu8
# 6
# menus_6
# 2
# menus_2
# 8
# menus_8
# 37
# menu6, menu2, menu4
# 6
# menus_6
# 2
# menus_2
# 4
# menus_4
# 38
# menu9, menu2, menu1
# 9
# menus_9
# 2
# menus_2
# 1
# menus_1
# 39
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 40
# menu2, menu1, menu5
# 2
# menus_2
# 1
# menus_1
# 5
# menus_5
# 41
# menu2, menu1, menu5
# 2
# menus_2
# 1
# menus_1
# 5
# menus_5
# 42
# menu2, menu4, menu5
# 2
# menus_2
# 4
# menus_4
# 5
# menus_5
# 43
# menu6, menu4, menu1
# 6
# menus_6
# 4
# menus_4
# 1
# menus_1
# 44
# menu2, menu4, menu5
# 2
# menus_2
# 4
# menus_4
# 5
# menus_5
# 45
# menu3, menu2, menu4
# 3
# menus_3
# 2
# menus_2
# 4
# menus_4
# 46
# menu6, menu3, menu2
# 6
# menus_6
# 3
# menus_3
# 2
# menus_2
# 47
# menu9, menu7, menu2
# 9
# menus_9
# 7
# menus_7
# 2
# menus_2
# 48
# menu6, menu2, menu4
# 6
# menus_6
# 2
# menus_2
# 4
# menus_4
# 49
# menu9, menu2, menu1
# 9
# menus_9
# 2
# menus_2
# 1
# menus_1
# 50
# menu2, menu4, menu5
# 2
# menus_2
# 4
# menus_4
# 5
# menus_5
# 51
# menu6, menu4, menu5
# 6
# menus_6
# 4
# menus_4
# 5
# menus_5
# 52
# menu9, menu6, menu4
# 9
# menus_9
# 6
# menus_6
# 4
# menus_4
# 53
# menu6, menu2, menu4
# 6
# menus_6
# 2
# menus_2
# 4
# menus_4
# 54
# menu6, menu7, menu9
# 6
# menus_6
# 7
# menus_7
# 9
# menus_9
# 55
# menu6, menu2, menu5
# 6
# menus_6
# 2
# menus_2
# 5
# menus_5
# 56
# menu9, menu2, menu1
# 9
# menus_9
# 2
# menus_2
# 1
# menus_1
# 57
# menu9, menu4, menu5
# 9
# menus_9
# 4
# menus_4
# 5
# menus_5
# 58
# menu6, menu2, menu4
# 6
# menus_6
# 2
# menus_2
# 4
# menus_4
# 59
# menu9, menu2, menu4
# 9
# menus_9
# 2
# menus_2
# 4
# menus_4
# 60
# menu6, menu1, menu4
# 6
# menus_6
# 1
# menus_1
# 4
# menus_4
# 61
# menu6, menu2, menu8
# 6
# menus_6
# 2
# menus_2
# 8
# menus_8
# 62
# menu9, menu6, menu5
# 9
# menus_9
# 6
# menus_6
# 5
# menus_5
# 63
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 64
# menu6, menu2, menu4
# 6
# menus_6
# 2
# menus_2
# 4
# menus_4
# 65
# menu9, menu2, menu6
# 9
# menus_9
# 2
# menus_2
# 6
# menus_6
# 66
# menu6, menu7, menu2
# 6
# menus_6
# 7
# menus_7
# 2
# menus_2
# 67
# menu6, menu1, menu9
# 6
# menus_6
# 1
# menus_1
# 9
# menus_9
# 68
# menu9, menu2, menu4
# 9
# menus_9
# 2
# menus_2
# 4
# menus_4
# 69
# menu2, menu4, menu5
# 2
# menus_2
# 4
# menus_4
# 5
# menus_5
# 70
# menu2, menu8, menu4
# 2
# menus_2
# 8
# menus_8
# 4
# menus_4
# 71
# menu6, menu2, menu4
# 6
# menus_6
# 2
# menus_2
# 4
# menus_4
# 72
# menu2, menu4, menu8
# 2
# menus_2
# 4
# menus_4
# 8
# menus_8
# 73
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 74
# menu9, menu2, menu1
# 9
# menus_9
# 2
# menus_2
# 1
# menus_1
# 75
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 76
# menu2, menu4, menu5
# 2
# menus_2
# 4
# menus_4
# 5
# menus_5
# 77
# menu6, menu4, menu5
# 6
# menus_6
# 4
# menus_4
# 5
# menus_5
# 78
# menu6, menu2, menu5
# 6
# menus_6
# 2
# menus_2
# 5
# menus_5
# 79
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 80
# menu9, menu2, menu6
# 9
# menus_9
# 2
# menus_2
# 6
# menus_6
# 81
# menu6, menu2, menu8
# 6
# menus_6
# 2
# menus_2
# 8
# menus_8
# 82
# menu6, menu4, menu5
# 6
# menus_6
# 4
# menus_4
# 5
# menus_5
# 83
# menu3, menu2, menu5
# 3
# menus_3
# 2
# menus_2
# 5
# menus_5
# 84
# menu6, menu7, menu5
# 6
# menus_6
# 7
# menus_7
# 5
# menus_5
# 85
# menu2, menu4, menu1
# 2
# menus_2
# 4
# menus_4
# 1
# menus_1
# 86
# menu6, menu1, menu4
# 6
# menus_6
# 1
# menus_1
# 4
# menus_4
# 87
# menu6, menu7, menu2
# 6
# menus_6
# 7
# menus_7
# 2
# menus_2
# 88
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 89
# menu6, menu2, menu4
# 6
# menus_6
# 2
# menus_2
# 4
# menus_4
# 90
# menu2, menu4, menu5
# 2
# menus_2
# 4
# menus_4
# 5
# menus_5
# 91
# menu6, menu3, menu2
# 6
# menus_6
# 3
# menus_3
# 2
# menus_2
# 92
# menu6, menu2, menu4
# 6
# menus_6
# 2
# menus_2
# 4
# menus_4
# 93
# menu6, menu8, menu9
# 6
# menus_6
# 8
# menus_8
# 9
# menus_9
# 94
# menu6, menu2, menu4
# 6
# menus_6
# 2
# menus_2
# 4
# menus_4
# 95
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 96
# menu6, menu2, menu1
# 6
# menus_6
# 2
# menus_2
# 1
# menus_1
# 97
# menu9, menu2, menu8
# 9
# menus_9
# 2
# menus_2
# 8
# menus_8
# 98
# menu2, menu8, menu4
# 2
# menus_2
# 8
# menus_8
# 4
# menus_4
#                           id  month  n_seconds_1  n_seconds_2  n_seconds_3  \
# 0  867285b116c063d5a8482f5be     10     5184.876      557.650      487.587
# 1  c82a7cbd2e00d9b66c06bcadc     10     3835.618     3275.128       43.806
# 2  f2d2b25073ccc298eced86897     10     3532.544      154.509       64.724
# 3  7818c92a58af0f2cb7c361738     10     3344.192      787.896      715.115
# 4  08773130c89b00852a36a6c5b     10     3011.760     1929.067     1183.204
#
#         carrier devicebrand  feature_0  feature_1  feature_2  ...  \
# 0      TURKCELL     samsung  -2.336352   2.567766  -0.494908  ...
# 1  TURK TELEKOM       Redmi  -2.561455   2.061736  -0.184511  ...
# 2      TURKCELL     samsung  -2.529918   3.358050  -0.851366  ...
# 3   VODAFONE TR     samsung  -2.922361   2.096124   0.060796  ...
# 4      TURKCELL     samsung  -1.703797   1.908199   0.647938  ...
#
#                  menus  menus_1   menus_2  menus_3  menus_4  menus_5  \
# 0  menu7, menu8, menu4    0.000     0.000      0.0  487.587      0.0
# 1  menu2, menu8, menu4    0.000  3835.618      0.0   43.806      0.0
# 2  menu6, menu2, menu1   64.724   154.509      0.0    0.000      0.0
# 3  menu6, menu2, menu8    0.000   787.896      0.0    0.000      0.0
# 4  menu6, menu2, menu9    0.000  1929.067      0.0    0.000      0.0
#
#     menus_6   menus_7   menus_8   menus_9
# 0     0.000  5184.876   557.650     0.000
# 1     0.000     0.000  3275.128     0.000
# 2  3532.544     0.000     0.000     0.000
# 3  3344.192     0.000   715.115     0.000
# 4  3011.760     0.000     0.000  1183.204
#
# [5 rows x 67 columns]

# %%
x = data.drop(columns=['menus','id','month','carrier','devicebrand','n_seconds_1','n_seconds_2','n_seconds_3','menus_1','menus_2','menus_3','menus_4','menus_5','menus_6','menus_7','menus_8','menus_9'])
y = data.menus.values.reshape(-1,1)
print(x.shape)
print(y.shape)
#x=(xdata-np.min(xdata))/(np.max(xdata)-np.min(xdata))
# Out:
# (99, 50)
# (99, 1)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=1)

# %%
import tensorflow as tf
model = tf.keras.models.Sequential()
print(x_train.shape)
print(y_train.shape)
model.add(tf.keras.layers.Dense(256, input_shape=(79,1), activation='sigmoid'))
model.add(tf.keras.layers.Dense(256, activation='sigmoid'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
# Out:
# (79, 50)
# (79, 1)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
print(y_train.shape)
print(x_train.shape)
model.fit(x_train, y_train, epochs=1000)
# Out:
# (79, 1)
# (79, 50)
# Epoch 1/1000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-212-80ae41f2cdb9> in <cell line: 3>()
#       1 print(y_train.shape)
#       2 print(x_train.shape)
# ----> 3 model.fit(x_train, y_train, epochs=1000)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1338, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1322, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1303, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1080, in train_step
#         y_pred = self(x, training=True)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_34" is incompatible with the layer: expected shape=(None, 79, 1), found shape=(None, 50)

# %%
model.evaluate(x_test, y_test)
